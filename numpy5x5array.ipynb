# %%
import pandas as pd
import numpy as np

# %%
array=np.random.randint(0, 51,size=(5,5))
print("Array:")
print(array)
# Out:
# Array:
# [[28 15 22 43 26]
#  [44 48 43 38  0]
#  [28 14 38 38 46]
#  [11 33 17 10 29]
#  [45 44 26 46 43]]

# %%
#her setirin ortacasyny tapmak
means=array.mean(axis=0)
print("Avearges",means)
# Out:
# Avearges [31.2 30.8 29.2 35.  28.8]

# %%
df=pd.DataFrame(means,columns=['mean
